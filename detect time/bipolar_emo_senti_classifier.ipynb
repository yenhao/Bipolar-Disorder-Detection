# %%
import pandas as pd
import numpy as np
import sklearn.metrics
import pytz
import os
from sklearn import preprocessing
from sklearn.externals import joblib
import multiprocessing as mp
from datetime import datetime, timedelta
import pickle

#import PatternVectorizer and SimpleClassifier
from pattern_classifier import  SimpleClassifier, PatternVectorizer

# %%
cls_persistence = 'data/simple_classifier_model.pkl.compressed'
pv_persistence = 'data/pattern_vectorizer.pkl.compressed'

cls = joblib.load(cls_persistence)
pv = joblib.load(pv_persistence)

# %% [markdown]
# ## Load Tweets

# %%
timezone_location_dict = {
    'Pacific Time (US & Canada)':'US/Pacific',
    'Central Time (US & Canada)':'US/Central',
    'Eastern Time (US & Canada)':'US/Eastern',
    'London':'Europe/London',
    'Sydney':'Australia/Sydney',
    'Tokyo':'Asia/Tokyo',
    'Africa/Nairobi':'Africa/Nairobi',
    'Arizona':'US/Arizona',
    'Kyiv':'Europe/Simferopol',
    'Europe/London':'Europe/London',
    'Atlantic Time (Canada)':'Atlantic/Canary',
    'Midway Island':'Pacific/Apia',
    'Auckland':'Pacific/Auckland',
    'Amsterdam':'Europe/Amsterdam',
    'Baghdad':'Asia/Riyadh',
    'Riyadh':'Asia/Riyadh',
    'Belgrade':'Europe/Belgrade',
    'Quito':'Pacific/Galapagos',
    'Pretoria':'Africa/Johannesburg',
    'Beijing':'Asia/Shanghai',
    'Hong Kong':'Asia/Shanghai',
    'Dublin':'Europe/Dublin',
    'Mountain Time (US & Canada)':'Mountain/US',
    'Hawaii':'Pacific/Honolulu',
    'Brisbane':'Australia/Brisbane',
    'Vienna':'Europe/Vienna',
    'Islamabad':'Asia/Karachi',
    'Casablanca':'Africa/Casablanca',
    'Yakutsk':'Asia/Yakutsk',
    'Tijuana':'America/Tijuana',
    'Johannesburg':'Africa/Johannesburg',
    'Mountain Time (US & Canada)':'US/Central',
    'Bangkok': 'Asia/Bangkok',
    'Harare': 'Africa/Harare',
    'Chennai': 'Asia/Kolkata',
    'Kolkata': 'Asia/Kolkata',
    'Brussels': 'Europe/Brussels',
    'Melbourne': 'Australia/Melbourne',
    'Alaska': 'US/Alaska',
    'Perth': 'Australia/Perth',
    'Denver':'America/Denver',
    'Los Angeles': 'America/Los_Angeles',
    'indiana': 'US/East-Indiana',
    'Vancouver': 'America/Vancouver',
    'Berlin': 'Europe/Berlin',
    'Kentucky': 'America/Kentucky/Louisville',
    'Copenhagen':'Europe/Copenhagen',
    'Athens': 'Europe/Athens',
    'Edinburgh': 'Etc/Greenwich',
    'Wellington': 'Asia/Anadyr',
    'Santiago': 'US/Pacific',
    'America/New_York': 'US/Eastern',
    'Paris': 'Europe/Paris',
    'Jakarta': 'Asia/Jakarta',
    'New Delhi': 'Asia/Calcutta',
    'Chicago': 'US/Central',
    'America/Chicago': 'US/Central',
    'Fiji': 'Pacific/Fiji',
    'US/Mountain': 'US/Mountain'
}

# %% [markdown]
# ### Load Patient TimeZone

# %%
def readPatientTimezone(folder, filename):
    time_dict = {}
    with open(folder + filename, 'r') as openfile:
        start = False
        for line in openfile.readlines():
            split = line.strip().split('\t')
            if split[1] == 'bernievassallo': start = True
            if split[2] != "None" and start:
                time_dict[split[1]] = split[2]
            else: 
                continue
    return time_dict

patient_timezone_dict = readPatientTimezone('','bipolar_user_timezone')
print(len(patient_timezone_dict))
# Out:
# 27

# %% [markdown]
# ### Load Patient Ill Time

# %%
bipolar_diagnosed_dict = {}

with open('bipolar_list') as f:
    for line in f.readlines():
        name, date = line.strip().split('\t')
        if name in patient_timezone_dict:
            if len(date.split('/')) == 3:
                bipolar_diagnosed_dict[name] = datetime.strptime(date, "%Y/%m/%d")
            elif len(date.split('/')) == 2:
                bipolar_diagnosed_dict[name] = datetime.strptime(date, "%Y/%m")
                
print(len(bipolar_diagnosed_dict))
# Out:
# 26

# %% [markdown]
# ### Read Patient Tweets

# %%
# Start from : bernievassallo
file_dir = 'patient_tweets/'
col = ['screen', 'id', 'datetime', 'text']
user_tweet_list = [pd.read_csv(file_dir+file, delimiter = '\t', names = col) for file in bipolar_diagnosed_dict]
print(len(user_tweet_list))
# Out:
# 26

# %% [markdown]
# ### Convert datetime_str to datetime and Adjust Datetime by Timezone

# %%
def to_local_timezone(local, orig_time):
    # -8 is because I collect data from taiwan which is +8 not +8
    utc_time = orig_time-timedelta(hours = 8)
    tz = pytz.timezone(local)
    return pytz.utc.localize(utc_time, is_dst=None).astimezone(tz)

# %%
# Before Adjust
user_tweet_list[0].datetime[0]
# Out:
# '2017-04-27 11:57:06'

# %%
for i,user_tweets in enumerate(user_tweet_list):
    user_timezone = patient_timezone_dict.get(user_tweets.screen[0])
    user_tweet_list[i].datetime = user_tweets.datetime.astype('datetime64[ns]').map(lambda x: to_local_timezone(timezone_location_dict[user_timezone], x))

# %%
# After Adjust
user_tweet_list[0].datetime[0]
# Out:
# Timestamp('2017-04-26 20:57:06-0700', tz='US/Pacific')

# %% [markdown]
# ### Filter Time

# %%
# Filter the time > 15month
def filterDiagnosedPeriod(user_tweets, diagnosed_time):
    # After Diagnosed 3month
    user_tweets = user_tweets[user_tweets.datetime <= (diagnosed_time + timedelta(weeks = 14))]
    # Before Diagnosed 1year
    user_tweets = user_tweets[user_tweets.datetime >= (diagnosed_time - timedelta(weeks = 54))]
    user_tweets.datetime = user_tweets.datetime.map(lambda x: x.strftime("%Y-%m-%d %H:%M:%S"))
    return user_tweets

# %%
time_filter_tweet_list = []
for i, user_tweets in enumerate(user_tweet_list):
    diagnosed_time = bipolar_diagnosed_dict.get(user_tweets.screen[0])
    temp_tweet_list = filterDiagnosedPeriod(user_tweets, diagnosed_time)
    if len(temp_tweet_list) > 0:
        time_filter_tweet_list.append(temp_tweet_list)

# %%
del user_tweet_list
len(time_filter_tweet_list)
# Out:
# 24

# %% [markdown]
# ## Query Emotion

# %%
def emotion_query(user_tweets):
    documentPatternVectors = pv.transform(user_tweets.text)

    # using two emotion, guess the one with the smallest rank
    Y_GUESS_2 = cls.get_top_emotion_ambiguous(documentPatternVectors, ascending=True, n=2)

    Guess_array = np.array(Y_GUESS_2)

    user_tweets['emotion1'] = Guess_array[:,0]
    user_tweets['emotion2'] = Guess_array[:,1]
    user_tweets['ambiguous'] = Guess_array[:,2]
    
    return user_tweets

# %% [markdown]
# ### Multi-Processing

# %%
pool = mp.Pool(processes=mp.cpu_count())
multi_res = [pool.apply_async(emotion_query, (user_tweets,)) for user_tweets in time_filter_tweet_list]
emo_user_tweet_list = [res.get() for res in multi_res]

# %%
del time_filter_tweet_list
print(len(emo_user_tweet_list))
# Out:
# 24

# %%
emo_user_tweet_list[0]
# Out:
#          screen         id             datetime  \
# 0     sobertony  sobertony  2017-04-26 20:57:06
# 1     sobertony  sobertony  2017-04-26 20:21:13
# 2     sobertony  sobertony  2017-04-26 20:15:44
# 3     sobertony  sobertony  2017-04-26 19:26:01
# 4     sobertony  sobertony  2017-04-26 19:13:38
# 5     sobertony  sobertony  2017-04-26 19:12:58
# 6     sobertony  sobertony  2017-04-26 18:49:40
# 7     sobertony  sobertony  2017-04-26 18:46:44
# 8     sobertony  sobertony  2017-04-26 18:44:21
# 9     sobertony  sobertony  2017-04-26 18:42:35
# 10    sobertony  sobertony  2017-04-26 18:34:34
# 11    sobertony  sobertony  2017-04-26 18:28:53
# 12    sobertony  sobertony  2017-04-26 18:27:50
# 13    sobertony  sobertony  2017-04-26 18:24:46
# 14    sobertony  sobertony  2017-04-26 18:20:08
# 15    sobertony  sobertony  2017-04-26 15:28:05
# 16    sobertony  sobertony  2017-04-26 13:35:10
# 17    sobertony  sobertony  2017-04-26 12:39:46
# 18    sobertony  sobertony  2017-04-26 09:36:51
# 19    sobertony  sobertony  2017-04-26 09:31:13
# 20    sobertony  sobertony  2017-04-26 07:50:45
# 21    sobertony  sobertony  2017-04-26 07:45:02
# 22    sobertony  sobertony  2017-04-26 06:27:42
# 23    sobertony  sobertony  2017-04-25 22:21:05
# 24    sobertony  sobertony  2017-04-25 22:19:07
# 25    sobertony  sobertony  2017-04-25 22:18:17
# 26    sobertony  sobertony  2017-04-25 22:17:27
# 27    sobertony  sobertony  2017-04-25 21:19:31
# 28    sobertony  sobertony  2017-04-25 20:50:11
# 29    sobertony  sobertony  2017-04-25 20:48:26
# ...         ...        ...                  ...
# 1008  sobertony  sobertony  2017-03-08 14:45:21
# 1009  sobertony  sobertony  2017-03-07 16:05:05
# 1010  sobertony  sobertony  2017-03-07 16:03:57
# 1011  sobertony  sobertony  2017-03-07 15:53:19
# 1012  sobertony  sobertony  2017-03-07 12:34:00
# 1013  sobertony  sobertony  2017-03-06 15:48:51
# 1014  sobertony  sobertony  2017-03-06 12:52:02
# 1015  sobertony  sobertony  2017-03-06 12:50:47
# 1016  sobertony  sobertony  2017-03-06 08:16:26
# 1017  sobertony  sobertony  2017-03-05 14:27:18
# 1018  sobertony  sobertony  2017-03-05 04:09:11
# 1019  sobertony  sobertony  2017-03-04 18:18:20
# 1020  sobertony  sobertony  2017-03-04 18:10:50
# 1021  sobertony  sobertony  2017-03-04 04:51:23
# 1022  sobertony  sobertony  2017-03-03 19:40:25
# 1023  sobertony  sobertony  2017-03-03 16:20:10
# 1024  sobertony  sobertony  2017-03-03 16:13:08
# 1025  sobertony  sobertony  2017-03-03 16:11:38
# 1026  sobertony  sobertony  2017-03-03 16:09:15
# 1027  sobertony  sobertony  2017-03-02 15:52:18
# 1028  sobertony  sobertony  2017-03-02 10:52:44
# 1029  sobertony  sobertony  2017-03-02 10:40:22
# 1030  sobertony  sobertony  2017-03-02 08:12:40
# 1031  sobertony  sobertony  2017-03-02 08:00:19
# 1032  sobertony  sobertony  2017-03-02 07:48:29
# 1033  sobertony  sobertony  2017-03-01 17:41:00
# 1034  sobertony  sobertony  2017-02-28 17:20:04
# 1035  sobertony  sobertony  2017-02-28 17:02:50
# 1036  sobertony  sobertony  2017-02-28 15:13:03
# 1037  sobertony  sobertony  2017-02-28 15:07:34
#
#                                                    text      emotion1  \
# 0     Interesting... I had no clue looked like some ...          fear
# 1                                You're crushing it Rev       disgust
# 2     Thanks man. I felt really good after 5th step ...      surprise
# 3     I love the #sobercount because it's one way to...         trust
# 4     Very isolated kind of work. Especially when hi...          fear
# 5     It's gets worse when your theology changes and...       disgust
# 6     When I worked as a pastor (before things blew ...       sadness
# 7     My psychologist was very glad that I'd found a...      surprise
# 8                   @boner_sober bro. What's happening?  anticipation
# 9     I would think burnout is a hugh problem. Espec...  anticipation
# 10    Honesty is about all I'm going to get out of t...       sadness
# 11                     sorry. Got it now #addictionchat           joy
# 12    That's one thing I've really enjoyed about my ...      surprise
# 13    I'm still fighting my addiction everyday, but ...          fear
# 14                             I'm in recovery. Day 71.  anticipation
# 15                                                  NaN      surprise
# 16      Why don't they have an emoji for the AA symbol?       disgust
# 17    That's a great reminder about rock bottom. I d...  anticipation
# 18    Welcome to #recoveryposse it gets better, litt...         trust
# 19                           pic.twitter.com/vlQ70sWuxV         trust
# 20    Awesome! Those big numbers always give me conf...      surprise
# 21    Today's #sobercount Just another kick-ass day ...  anticipation
# 22         I got that for addiction & bipolar behavior.           joy
# 23    I'm ok with the diagnosis. My stuff is fairly ...         anger
# 24    I'm looking forward to every new day. It's get...  anticipation
# 25                          Best choice every danm day.  anticipation
# 26    That's some serious sober time. Lateness is ok...  anticipation
# 27                                  Lol. That's awesome  anticipation
# 28    I dropped my insurance this guy is flat rate a...          fear
# 29                                          Mad as fuck         anger
# ...                                                 ...           ...
# 1008  That's what I'm hoping, main concern is my mom...          fear
# 1009  I'm always late to the party, but I can catch ...         anger
# 1010  It takes 2+ months for a new behavior to becom...         trust
# 1011                                 I love that stuff.         anger
# 1012  My hope in recovery is that I won't be powerle...      surprise
# 1013                    lol. I'm still in the Caribbean      surprise
# 1014  I had that feeling for several days week two. ...      surprise
# 1015  yes totally with you on the boring part, hang ...         anger
# 1016  I was grossed out in every way, probably helpe...      surprise
# 1017  Day 19 sober. Somewhere beautiful but surround...         anger
# 1018                          congrats on double digits           joy
# 1019  they used to put karaoke night on cable TV in ...       sadness
# 1020  Day 18 sober. A little celebration with old sc...      surprise
# 1021  I woke up to discover no coffee in the house A...          fear
# 1022     it's Haiti and I'm the only guy with the money      surprise
# 1023                             yuck about the cabbage       disgust
# 1024  I can't find any TV shows where alcohol isn't ...      surprise
# 1025  my new language in Haiti does that with every ...      surprise
# 1026  I'm about to head out too (my 1st time since g...           joy
# 1027  totally agree. i am seeing self-deception in a...         anger
# 1028  I felt like a creepy jealous boyfriend, I'm lu...          fear
# 1029  Anyone used to search their own cell phone to ...      surprise
# 1030                               that's my life story  anticipation
# 1031                often wonder how I didn't die young      surprise
# 1032  Anyone else drink Listerine when they were tee...      surprise
# 1033  it's 95° today in Port-au-Prince, I woke up de...           joy
# 1034  that's the last thing I need I'm already dread...           joy
# 1035  Thanks! I loved reading your story. Inspiring ...      surprise
# 1036          #NewProfilePic pic.twitter.com/jpZWJuH6WQ         trust
# 1037  I'm celebrating 2 weeks #sober by joining Twitter  anticipation
#
#           emotion2 ambiguous
# 0         surprise     false
# 1     anticipation      true
# 2              joy     false
# 3            anger     false
# 4            anger     false
# 5            anger      true
# 6         surprise     false
# 7             fear     false
# 8         surprise     false
# 9            anger     false
# 10           anger     false
# 11        surprise      true
# 12           anger     false
# 13    anticipation     false
# 14             joy     false
# 15            fear      true
# 16           anger      true
# 17        surprise     false
# 18    anticipation     false
# 19           anger      true
# 20           trust     false
# 21        surprise     false
# 22        surprise     false
# 23        surprise     false
# 24             joy     false
# 25             joy      true
# 26        surprise     false
# 27        surprise     false
# 28        surprise     false
# 29            fear     false
# ...            ...       ...
# 1008      surprise     false
# 1009      surprise     false
# 1010      surprise     false
# 1011      surprise     false
# 1012          fear     false
# 1013       sadness     false
# 1014       sadness     false
# 1015      surprise     false
# 1016         anger     false
# 1017       sadness     false
# 1018      surprise     false
# 1019      surprise     false
# 1020          fear     false
# 1021         anger     false
# 1022          fear      true
# 1023  anticipation      true
# 1024  anticipation     false
# 1025          fear     false
# 1026          fear     false
# 1027      surprise     false
# 1028       disgust     false
# 1029       sadness     false
# 1030      surprise      true
# 1031          fear     false
# 1032         anger     false
# 1033      surprise     false
# 1034          fear     false
# 1035  anticipation     false
# 1036         anger      true
# 1037       disgust     false
#
# [1038 rows x 7 columns]

# %% [markdown]
# ### Normal Way

# %%
# emo_user_tweet_list = []
# for i, user_tweets in enumerate(user_tweet_list):
#     try:
#         emo_user_tweet_list.append(emotion_query(user_tweets))
#     except:
#         print(i)

# %% [markdown]
# ## Query Sentiment 140

# %%
import re
import urllib
import json

# %%
# function to delete url
def del_url(line):
    return re.sub(r'(\S*(\.com).*)|(https?:\/\/.*)', "", line)
# replace tag
def checktag(line): 
    return re.sub(r'\@|\#', "", line)
# Some special character
def checkSpecial(line):
    return line.replace('♡', 'love ').replace('\"','').replace('“','').replace('”','').replace('…','...').replace('’','\'').replace('•', '').replace('–','-')

def sendto140(line):
        query_string = '{"data": ['
        # username, date, datetime, content 
        query_string += '{"text": "' + checkSpecial(checktag(del_url(str(line).strip()))) + '"},'

        query_string = query_string[:-1] + ']}'
        try:
            data = query_string.encode('utf-8');
            response = urllib.request.urlopen('http://www.sentiment140.com/api/bulkClassifyJson', data) # request to server     
            page = response.read() # get the response     
            # print page # print the result     
            query_result = json.loads((page).decode('utf-8')) # parse the result. The result is in JSON format
            return sentiment_dict[int(query_result["data"][0]["polarity"])]
        except:
            print('\n{} - Fail : {}'.format( datetime.now().strftime("%Y/%m/%d %H:%M:%S"), query_string))
            return sentiment_dict[2]



sentiment_dict = {
                0:-1,
                2: 0,
                4: 1
                }

# %%
for i, emo_user_tweets in enumerate(emo_user_tweet_list):
    try:
        print('{}. {} : {}'.format(i, emo_user_tweets['screen'][0], len(emo_user_tweets)))
        emo_user_tweet_list[i]['sentiment'] = emo_user_tweets.text.apply(lambda t: sendto140(t))
    except:
        print(i)
# Out:
# 0. sobertony : 1038
#
# 2017/05/08 22:47:25 - Fail : {"data": [{"text": "That's what make it awesome. I'm so new to this but I'm​amazed that the hard days come and go. The good ones are worth it."}]}
#
# 2017/05/08 22:47:26 - Fail : {"data": [{"text": "Thank you for sharing. That's awesome​."}]}
#
# 2017/05/08 22:47:29 - Fail : {"data": [{"text": "That's a huge​ number. You're getting it done."}]}
#
# 2017/05/08 22:47:37 - Fail : {"data": [{"text": "Thank you. I'm​ glad for Twitter friends like you."}]}
#
# 2017/05/08 22:47:47 - Fail : {"data": [{"text": "Start with love. Then use I statements not accusations. I am worrying​ about you."}]}
#
# 2017/05/08 22:47:51 - Fail : {"data": [{"text": "I'm​ glad for that because I'm not as rich as I used to imagine when I was drinking"}]}
#
# 2017/05/08 22:48:25 - Fail : {"data": [{"text": "Clever advice doesn't help much, but I'll welcome any friend who's​ been through it too. "}]}
#
# 2017/05/08 22:48:32 - Fail : {"data": [{"text": "A friend said she's​ my new addiction, I don't want that to be true because she's very important to me and I don't want to mess this up."}]}
#
# 2017/05/08 22:48:33 - Fail : {"data": [{"text": "Then there's a pair of us — don't tell! They'd banish us, you know. (Emily Dickinson)"}]}
#
# 2017/05/08 22:48:47 - Fail : {"data": [{"text": "I prayed only in public for several years. I got away with a shit​load of hypocrisy."}]}
#
# 2017/05/08 22:48:50 - Fail : {"data": [{"text": "Even when I sleep, my dreams conjure up anxiety, loss, sentimental confusion and depravity. Every. Single. Second. Of the day.'
# sobertony	sobertony	2017-04-10 02:36:01	I act like I'm a tough guy, but my girlfriend picks out my clothes... Like every morning.... Even 1700 miles away.... homesick
# sobertony	sobertony	2017-04-10 00:42:07	I heard more reality in one AA meeting than I did in 10 yrs of sermons.
# sobertony	sobertony	2017-04-10 00:40:28	And why don't pastors talk about real life? Are they playing it safe and keeping​ everything general and non-offensive? AskSteveAustin
# sobertony	sobertony	2017-04-09 22:49:32	It just feels too safe and like they are afriad to offend anyone. Probably just my personal hangup about proper behavior.
# sobertony	sobertony	2017-04-09 22:43:01	I wondered about those women only meetings
# sobertony	sobertony	2017-04-09 22:35:44	I don't want to listen to a preacher who is not allowed to cuss. Too compliant.
# sobertony	sobertony	2017-04-09 22:25:34	I went not amazing but a personal milestone for facing the anxiety . Last January was ready but then got drunk instead. sober win today
# sobertony	sobertony	2017-04-09 21:39:36	My neck and back are killing me from this maybe got a little carried away
# sobertony	sobertony	2017-04-09 20:30:40	Counting days reminds me to make this specific one awesome. No do-over. Today is 54 and it's going to be epic. odaat xa soberlife
# sobertony	sobertony	2017-04-09 20:27:14	It's been awesome and hard, but mostly awesome.
# sobertony	sobertony	2017-04-09 20:26:22	Oh... That's not as cute as I was thinking. I got to visit my dogs yesterday, but if forgot to make a selfie
# sobertony	sobertony	2017-04-09 20:24:48	It's a lot of anxiety for one day.
# sobertony	sobertony	2017-04-09 20:08:24	She had a good day
# sobertony	sobertony	2017-04-09 20:07:14	I'm craving fish for breakfast too
# sobertony	sobertony	2017-04-09 20:02:24	One new development. My 8 yr old added me on Skype. He's blowing up my phone with stickers and emojis. It's hilarious and good
# sobertony	sobertony	2017-04-09 20:00:25	I'm still feeling like a reformed gollum
# sobertony	sobertony	2017-04-09 19:56:02	They had a blast, almost as much fun as me. 3 months ago I would have been drinking and barfing on that thing. sobriety is better
# sobertony	sobertony	2017-04-09 19:54:32	I think he was big hair shaming.
# sobertony	sobertony	2017-04-09 19:53:45	I think a few level stops with a decent view would be nice, then the hills wouldn't be so annoying
# sobertony	sobertony	2017-04-09 19:52:34	Yes! I'm going with the awesome today
# sobertony	sobertony	2017-04-09 19:51:43	We'll see. I may bail after act 1
# sobertony	sobertony	2017-04-09 19:51:25	I think the first church​I chose for the architecture and to review some childhood memories
# sobertony	sobertony	2017-04-09 19:50:02	Do you like it? I am nervous about the social stuff
# sobertony	sobertony	2017-04-09 19:49:33	I think that's what I'm looking forward to finding, more than a visit for sure.
# sobertony	sobertony	2017-04-09 19:49:03	Agreed. I worked for a unhealthy church for 10 yrs, but even so miss the good people. They still send me cards.
# sobertony	sobertony	2017-04-09 19:47:10	Agree. I'm definitely still a heritic
# sobertony	sobertony	2017-04-09 19:46:36	9:00 small UMC church from my teenage years, then 10:45 a black church with a pastor who always inspired me.
# sobertony	sobertony	2017-04-09 10:44:11	Thank you for the helpful answers iamsteveaustin Cool new podcast, get your questions answered AskSteveAustin
# sobertony	sobertony	2017-04-09 09:50:24	Scouting churches on the net, it's been a while posting this so I don't chicken out. Bust my balls (metaphor) if I don't follow through.
# sobertony	sobertony	2017-04-09 09:19:46	Awesome. I'll check it out
# sobertony	sobertony	2017-04-08 23:20:19	Oh should have said shitty ... I've never shit that long in one setting
# sobertony	sobertony	2017-04-08 22:55:14	Damn I want a baby donkey
# sobertony	sobertony	2017-04-08 22:54:30
# sobertony	sobertony	2017-04-08 22:54:00	Good point. Zero desire to drink, just overwhelmed
# sobertony	sobertony	2017-04-08 22:51:49	That's very encouraging. I'm not sure how to make those connections. Just trying to show up today
# sobertony	sobertony	2017-04-08 22:50:18	I'm well - then I'm not - then we'll again - after that it's uncertain. I wish there was a pattern.
# sobertony	sobertony	2017-04-08 22:49:24	Shiting 90 minutes of life, opened Twitter to find so much help. Seriously, I follow all the best people. recoveryposse
# sobertony	sobertony	2017-04-08 22:48:08	That would be good. My memory isn't..... What were you saying???
# sobertony	sobertony	2017-04-08 22:45:13	Why can't I just be happy? Do what people want me to do. Feel what I'm supposed to feel. Not flake out and screws up everyone's life.
# sobertony	sobertony	2017-04-08 21:15:21	Oh shit. I hate being predictable.
# sobertony	sobertony	2017-04-08 20:18:23	I want to re tweet this every morning, sometimes 4 times.
# sobertony	sobertony	2017-04-08 19:00:11	Thank you. I need to keep hearing that.
# sobertony	sobertony	2017-04-08 18:49:10	That's the plan but I still feel like I ruined everyone's life.
# sobertony	sobertony	2017-04-08 18:48:23	Just facing facts about how my actions caused a lot of harm to the kids. I walked out and don't know how to come back.
# sobertony	sobertony	2017-04-08 18:47:14	They two oldest really needed to hear it wasn't their fault, that they didn't fail the family somehow. Great kids but they carry too much
# sobertony	sobertony	2017-04-08 18:44:00	Alcohol is cunning, baffling and powerful --- and we were gullible, confused, and weak. recovery means that shit is over.
# sobertony	sobertony	2017-04-08 18:42:58	Today's program is brought to you by the number 53.
# sobertony	sobertony	2017-04-08 06:59:02	Thank you. Even the hard days are better than my best days drinking
# sobertony	sobertony	2017-04-08 06:57:55	Thanks. I'm a little whinny without my afternoon nap lol. Got some jogging so I'm back in beast mode
# sobertony	sobertony	2017-04-08 06:56:27	I'm sorry to hear that, keep getting back up. Somebody said progress is what matters most, not perfection
# sobertony	sobertony	2017-04-08 06:55:20	It was my favorite thing today
# sobertony	sobertony	2017-04-08 04:22:09	Guilt like I did some super destructive things that really screwed up their lives. Jeus knows that all too well.
# sobertony	sobertony	2017-04-08 04:20:43	Uhhh. I didn't get too specific yet. I still gotta talk about that one.
# sobertony	sobertony	2017-04-08 04:19:34	I'm sorry, but you left it open.
# sobertony	sobertony	2017-04-08 04:17:31	Hey I'm rooting for you. Keep posting
# sobertony	sobertony	2017-04-08 04:16:33	Thank you. I need to hear that. I'm acting tough but today kinda sucked
# sobertony	sobertony	2017-04-08 04:14:58	It's a movie called fight club. A family fav with me and the teens
# sobertony	sobertony	2017-04-08 02:36:03	Drunk me was a wimpy man-child, pouting, resentful, abounding in self pity. recovery means growing up.
# sobertony	sobertony	2017-04-08 02:13:25	13 for me, no wonder my brain is defective & I'm always always nervous
# sobertony	sobertony	2017-04-08 02:12:06	Yup. 3rd day. 3 meetings. Once to counseling. Once to visit the kids. The guilt is really heavy right now
# sobertony	sobertony	2017-04-08 02:11:16	I did wait until my mom left for work
# sobertony	sobertony	2017-04-08 02:10:43	I couldn't decide. I am very promiscuous with my metaphors.
# sobertony	sobertony	2017-04-08 02:10:00	It was a lot of stress just talking to the older too. Guilt is heavy when you wreck a whole family.
# sobertony	sobertony	2017-04-08 02:09:07	Oh wow. Came up Baptist & Pentacostal so we didn't have that. I did have a stash in my desk later when k had a church job
# sobertony	sobertony	2017-04-08 02:08:05	It was the perfect way to strike back after the shit the first half of that case did to me in January
# sobertony	sobertony	2017-04-08 01:00:00	It was so much fun.
# sobertony	sobertony	2017-04-08 00:29:58	Random sober landmark. The job where I first got drunk at work. Night security guard 2002. Bible College days smh
# sobertony	sobertony	2017-04-07 22:28:12	Made some progress yesterday.
# sobertony	sobertony	2017-04-07 22:26:32	Absolutely. That's my new worst nightmare that my kids have to experience the hell of ADDICTION in their own heads. Bad enough in the house.
# sobertony	sobertony	2017-04-07 22:25:02	Yes, I wasn't some cash on those once too!
# sobertony	sobertony	2017-04-07 22:23:12	Cheapest therapy I've had all week
# sobertony	sobertony	2017-04-07 22:22:18	Kick ass or go home. I'm learning to forgive myself, but I hate the fuck out of my addiction.
# sobertony	sobertony	2017-04-07 22:20:47	Breaking things before breakfast, good way to get the blood flowing.
# sobertony	sobertony	2017-04-07 22:19:47	Amazing. That 2x4 found it's true potential.
# sobertony	sobertony	2017-04-07 22:19:11	Thanks. It was a good way to start the day.
# sobertony	sobertony	2017-04-07 22:17:48	Me too
# sobertony	sobertony	2017-04-07 22:02:47	Talked about my recovery with my teenagers last night. They said I was like TYLER DURDEN gone sober . I'll take that anyway.
# sobertony	sobertony	2017-04-07 20:27:24	Not you guys. The people that remember drunk Tony
# sobertony	sobertony	2017-04-07 19:55:44	So that's like punk rock or boy band pop?
# sobertony	sobertony	2017-04-07 19:54:32	I was insanely determined and strong willed in the absolute worst direction.
# sobertony	sobertony	2017-04-07 19:54:01	I found my old beer stash, then the killings began. recovery xa soberposse
# sobertony	sobertony	2017-04-07 18:59:43	Thank you! It's been a ride.
# sobertony	sobertony	2017-04-07 18:58:57	Thanks man. It's getting better just lost of raw emotion back here in my former hometown
# sobertony	sobertony	2017-04-07 18:58:15	It feels awesome. The hit me this week, I'm visiting​ family I destroyed etc., But still kicking ADDICTION's ass.
# sobertony	sobertony	2017-04-07 18:56:29	Hey let's kick some ass today. I found some old beer cans and I'm going to violently destroy them on video
# sobertony	sobertony	2017-04-07 18:55:51	Oh yes. Everyone here is waiting for me to flake out again but they're wrong. I'm staying at least two weeks"}]}
#
# 2017/05/08 22:49:01 - Fail : {"data": [{"text": "Don't have to self-stalk my cellphone​ for clues. "}]}
#
# 2017/05/08 22:49:09 - Fail : {"data": [{"text": "Green Day, U2, Norah​ Jones, Mumford and Sons, Sufjan Stevens, Lecrae, White Rabbits, 21 Pilots, Derek Webb, Toby Mac, Lighthouse & Whaler,"}]}
#
# 2017/05/08 22:49:13 - Fail : {"data": [{"text": "It's cool. I'm​ 49% bullshit when I talk, the other 51% is incoherent. Recovery community is a beautiful thing because we're all a mess."}]}
#
# 2017/05/08 22:49:14 - Fail : {"data": [{"text": "All is forgiven. We all have a common enemy. I'm​ a newbie but being public has helped me find some new friends. recoveryposse xa "}]}
#
# 2017/05/08 22:49:16 - Fail : {"data": [{"text": "Congratulations! It's an amazing feeling​."}]}
#
# 2017/05/08 22:49:25 - Fail : {"data": [{"text": "That's​ amazing. Congratulations"}]}
#
# 2017/05/08 22:50:11 - Fail : {"data": [{"text": "5) works with tiny bandwidth when you're​ almost off the grid"}]}
#
# 2017/05/08 22:50:18 - Fail : {"data": [{"text": "They are underestimating​ you. Try bipolar^2"}]}
#
# 2017/05/08 22:50:21 - Fail : {"data": [{"text": "With​ all the excessive airport security inflicted on passengers why not a simple breathalyzer for every pilot? "}]}
#
# 2017/05/08 22:50:26 - Fail : {"data": [{"text": "It takes 2+ months for a new behavior to become automatic — 66 days avg, sometimes 254 days "}]}
# 1. f0reverliving : 924
#
# 2017/05/08 22:52:00 - Fail : {"data": [{"text": "Danielle is fond trying. ️"}]}
#
# 2017/05/08 22:52:24 - Fail : {"data": [{"text": "I'm so done having to practically begging to be in people lives. ️"}]}
#
# 2017/05/08 22:53:24 - Fail : {"data": [{"text": "( ︶︿︶)_╭∩╮ mondayfeeling"}]}
# 2. suejamie2 : 2405
# 3
# 4. bunnyelephant : 4657
#
# 2017/05/08 23:01:33 - Fail : {"data": [{"text": "what happened at the end of hs? why werent u there ... — oh god , I dont want to go through this again. But ... "}]}
#
# 2017/05/08 23:01:33 - Fail : {"data": [{"text": "What did anal feel like — Fuckin hurts dude "}]}
#
# 2017/05/08 23:01:34 - Fail : {"data": [{"text": "Have u ever done anal and if u have did u like it? — I said it on twitter before lol idk how girls do it "}]}
#
# 2017/05/08 23:01:34 - Fail : {"data": [{"text": "give us a hint about who the girl is — She a bitch "}]}
#
# 2017/05/08 23:01:39 - Fail : {"data": [{"text": "why dont you like that girl — I said it in my other question/answer. "}]}
#
# 2017/05/08 23:01:39 - Fail : {"data": [{"text": "expose her !! — Dude I wish I could but I don't need drama rn from ... "}]}
#
# 2017/05/08 23:01:40 - Fail : {"data": [{"text": "Did she go to your hs? — Yes :/ "}]}
#
# 2017/05/08 23:01:40 - Fail : {"data": [{"text": "Expose the bitch lol — LMAO I definitely would but like I said, she talks ... "}]}
#
# 2017/05/08 23:01:41 - Fail : {"data": [{"text": "Don't be pussy say it — Lmao I am a pussy :( "}]}
#
# 2017/05/08 23:01:41 - Fail : {"data": [{"text": "which twitter user do you absolutely hate? — I have one but I won't reveal her bc she'll talk ... "}]}
#
# 2017/05/08 23:01:41 - Fail : {"data": [{"text": "What do you look for in a guy? — My most important requirement is a guy who isnt afr... "}]}
#
# 2017/05/08 23:01:42 - Fail : {"data": [{"text": "biggest youve ever had — idk exact inches, but the guy Im talking to rn, LOV... "}]}
#
# 2017/05/08 23:01:43 - Fail : {"data": [{"text": "tbh i love ypur body — Thank you so much! "}]}
#
# 2017/05/08 23:01:46 - Fail : {"data": [{"text": "Top five favorite twitter accounts/ mutuals — lmaogtfo_, ALEXIAISRATCHET, jstcwarrior, sheslulu, ... "}]}
#
# 2017/05/08 23:02:39 - Fail : {"data": [{"text": "TRDYKUVYONPIJ'LJOUYFUTRSRÉWREWATTUTOIBL "}]}
#
# 2017/05/08 23:02:40 - Fail : {"data": [{"text": "Your tits are perfect, i can only imagine what your... — omg "}]}
#
# 2017/05/08 23:02:40 - Fail : {"data": [{"text": "You're so fucking sexy, the things i'd do to for yo... — I would crush you dude "}]}
#
# 2017/05/08 23:02:41 - Fail : {"data": [{"text": "Just message back, we can get your later, i'll show... — BOIIIIII..... "}]}
#
# 2017/05/08 23:02:41 - Fail : {"data": [{"text": "You accepting nudes from black guys? — WHO SAID I WAS ACCEPTING NUDES IN THE FIRST PLACE "}]}
#
# 2017/05/08 23:02:41 - Fail : {"data": [{"text": "Your tits are the best. — thank you boo "}]}
#
# 2017/05/08 23:02:41 - Fail : {"data": [{"text": "Lemme dick you down. — why "}]}
#
# 2017/05/08 23:02:42 - Fail : {"data": [{"text": "Can I get yah snap — whas ya name "}]}
#
# 2017/05/08 23:02:42 - Fail : {"data": [{"text": "We sent selfies to eachother, you forgot to reply t... — im sorry, theres alot going on rn lol "}]}
#
# 2017/05/08 23:02:42 - Fail : {"data": [{"text": "I wouldn't slap you with it unless where actually d... — idk which one you are , I got like 2 other ppl in m... "}]}
#
# 2017/05/08 23:02:42 - Fail : {"data": [{"text": "Black or white — If you thinking of being my baby , it dont matter i... "}]}
#
# 2017/05/08 23:02:43 - Fail : {"data": [{"text": "Trust me i'm packing heat, send nudes and i'll slap... — SLAP ME WITH IT LOL "}]}
#
# 2017/05/08 23:02:43 - Fail : {"data": [{"text": "we have talked before, uve sent nudes before, any c... — Im losing feeling in my legs, hands and mouth as of... "}]}
#
# 2017/05/08 23:02:43 - Fail : {"data": [{"text": "cc? x — curious cat "}]}
#
# 2017/05/08 23:02:43 - Fail : {"data": [{"text": "How tall would you want yah boyfriend to be , I'm 6... — buddy,...Im gonna turn 20... "}]}
#
# 2017/05/08 23:02:43 - Fail : {"data": [{"text": "If I gave you my snao would you add me — depend who u r "}]}
#
# 2017/05/08 23:02:44 - Fail : {"data": [{"text": "What do you mean bOY you must want a pounding. do... — wheres ur cc at, i wanna ask how big ya meat is "}]}
#
# 2017/05/08 23:02:44 - Fail : {"data": [{"text": "Cause your very beautiful and unique — thank you "}]}
#
# 2017/05/08 23:02:44 - Fail : {"data": [{"text": "Send me nudes and snap — WHY DO YALL WANT MY NUDES "}]}
#
# 2017/05/08 23:02:44 - Fail : {"data": [{"text": "ya you can have it, or u can just dm me — lol ok "}]}
#
# 2017/05/08 23:02:45 - Fail : {"data": [{"text": "I wanna give you a good pounding x — .....bOY... "}]}
#
# 2017/05/08 23:02:45 - Fail : {"data": [{"text": "You should lowkey DM me nudes, you're perfection. — come out of the darkness, oh anonymous one "}]}
#
# 2017/05/08 23:02:45 - Fail : {"data": [{"text": "will you send me some nudes tonight — Can i ha yo numba ? "}]}
#
# 2017/05/08 23:02:45 - Fail : {"data": [{"text": "You're literally so perfect, your body is just, ah... — Thank you sm "}]}
#
# 2017/05/08 23:02:46 - Fail : {"data": [{"text": "Where are your nudes posted — LMFAOOO... I dont post my nipples and my pussy, but... "}]}
#
# 2017/05/08 23:02:56 - Fail : {"data": [{"text": "TBH .... — ????? "}]}
#
# 2017/05/08 23:02:57 - Fail : {"data": [{"text": "You deepthroat too ? — Yall tryna get me to hoe around or what "}]}
#
# 2017/05/08 23:02:57 - Fail : {"data": [{"text": "You ever been ate out? Describe that shitttt — Why are yall askin me the sexual questions lmao ... "}]}
#
# 2017/05/08 23:02:58 - Fail : {"data": [{"text": "HOW COUKD HE NOT STICK IT INLMAOOO — LMFAO IDEK IF IT WAS BECAUSE HE COULDNT FIND THE HO... "}]}
#
# 2017/05/08 23:02:58 - Fail : {"data": [{"text": "what did you tell him and do — GIRL , I tried sucking his dick but my head was goi... "}]}
#
# 2017/05/08 23:02:58 - Fail : {"data": [{"text": "and that was it when it was hard? — BITCH YES "}]}
#
# 2017/05/08 23:02:58 - Fail : {"data": [{"text": "how small was it — imagine the size of your pinky "}]}
#
# 2017/05/08 23:02:59 - Fail : {"data": [{"text": "How you got a sugar daddy?? But got an Android ... — I dont have a sugar daddy anymore and I got my phon... "}]}
#
# 2017/05/08 23:02:59 - Fail : {"data": [{"text": "who has the smallest dick you've fucked from bhs? — LMFAOOOOOOOOOOOOO I wont reveal his name and but th... "}]}
#
# 2017/05/08 23:02:59 - Fail : {"data": [{"text": "how old was he — 34, my son, I swear, yall little shits dont know ho... "}]}
#
# 2017/05/08 23:02:59 - Fail : {"data": [{"text": "Can I suck on your tits — bruh....lmfao "}]}
#
# 2017/05/08 23:02:59 - Fail : {"data": [{"text": "Best dick youve had? — LMFAO The sugar daddy I was with last month, got po... "}]}
#
# 2017/05/08 23:03:00 - Fail : {"data": [{"text": "You like anal? — who even likes anal besides cishet men and those wh... "}]}
#
# 2017/05/08 23:03:00 - Fail : {"data": [{"text": "How tall r u — 5'4 "}]}
#
# 2017/05/08 23:03:00 - Fail : {"data": [{"text": "How big ya titties — 38DD brah "}]}
#
# 2017/05/08 23:03:00 - Fail : {"data": [{"text": "How tall r u — 5'4 "}]}
#
# 2017/05/08 23:03:01 - Fail : {"data": [{"text": "So when you gunna let me hit from the back and eat ... — OMFGVVVYCDDSSUIYKUBOIGUTFES "}]}
#
# 2017/05/08 23:03:09 - Fail : {"data": [{"text": "It's me boo — omg theres 2 of you "}]}
#
# 2017/05/08 23:03:10 - Fail : {"data": [{"text": "It's me — who is me? "}]}
#
# 2017/05/08 23:03:10 - Fail : {"data": [{"text": "Nah never — show your face, lol "}]}
#
# 2017/05/08 23:03:10 - Fail : {"data": [{"text": "What to big ? You not about that life — u might be lying "}]}
#
# 2017/05/08 23:03:10 - Fail : {"data": [{"text": "It's 9 come get it — Lol bruh "}]}
#
# 2017/05/08 23:03:10 - Fail : {"data": [{"text": "Do you do anal ? — FUCK THAT SHIT "}]}
#
# 2017/05/08 23:03:10 - Fail : {"data": [{"text": "I'd nut in you — LMFAO depends how big your dick is looool "}]}
#
# 2017/05/08 23:03:11 - Fail : {"data": [{"text": "How do you get sugar daddies? — sugar daddy websites or just regular social media lol "}]}
#
# 2017/05/08 23:03:13 - Fail : {"data": [{"text": "How many sugar daddies you got? — I had 3 but I lost connection with them or they wer... "}]}
#
# 2017/05/08 23:03:13 - Fail : {"data": [{"text": "dam, im the opposite of that — LMAOOOOOO Im sorry forgive me "}]}
#
# 2017/05/08 23:03:19 - Fail : {"data": [{"text": "what type of guys are u into? — tall guys with beards "}]}
#
# 2017/05/08 23:03:19 - Fail : {"data": [{"text": "tbh your body is amazing — thank you babe "}]}
#
# 2017/05/08 23:03:19 - Fail : {"data": [{"text": "you single? — unfortunately, yes "}]}
#
# 2017/05/08 23:03:19 - Fail : {"data": [{"text": "why you so fine?? — Idk, Im hot by nature "}]}
#
# 2017/05/08 23:04:31 - Fail : {"data": [{"text": "¯\_(ツ)_/¯ "}]}
#
# 2017/05/08 23:06:32 - Fail : {"data": [{"text": "WHAT IF THEY BROUGHT BACK BEYONCÉ AND DID TELEPHONE"}]}
#
# 2017/05/08 23:07:18 - Fail : {"data": [{"text": "I spent another $15 and now I have $6 ¯\_(ツ)_/¯"}]}
#
# 2017/05/08 23:07:19 - Fail : {"data": [{"text": "I ordered a lot of things yesterday , so much that I spent $450 ¯\_(ツ)_/¯"}]}
#
# 2017/05/08 23:07:23 - Fail : {"data": [{"text": "When you have $475 and spend it on clothes and perfume ¯\_(ツ)_/¯"}]}
#
# 2017/05/08 23:07:30 - Fail : {"data": [{"text": "BreezaSonrisa girl , every month they say the world is gonna end so I'm like ¯\_(ツ)_/¯"}]}
#
# 2017/05/08 23:08:05 - Fail : {"data": [{"text": "jaaychelle \_(ツ)_/¯"}]}
#
# 2017/05/08 23:08:34 - Fail : {"data": [{"text": "ALEXIAISRATCHET ¯\_(ツ)_/¯"}]}
#
# 2017/05/08 23:09:55 - Fail : {"data": [{"text": "PackerFaithful I don't even have a 5 head lmao but don't come for feminists if you don't know what you're talking about ️"}]}
#
# 2017/05/08 23:10:57 - Fail : {"data": [{"text": "Émeline // emiliasbee -ur so perfect ong -I love your hair -I've never seen you on my TL before -but I'm glad I seen you rn! -pretty name"}]}
#
# 2017/05/08 23:13:58 - Fail : {"data": [{"text": "HAPPY FATHERS DAY ARE YOU DADDYS LITTLE GIRL SEND THIS TO OF YOUR ️ SUGAR DADDIES"}]}
#
# 2017/05/08 23:14:25 - Fail : {"data": [{"text": "gildaolmos I tried to educate one but then one came in calling me a fat bitch and I was like ¯\_(ツ)_/¯"}]}
# 5. inaseaofemotion : 1147
# 6. complicatedcon : 3253
#
# 2017/05/08 23:19:53 - Fail : {"data": [{"text": "please be okay angel — :( "}]}
#
# 2017/05/08 23:21:55 - Fail : {"data": [{"text": "i wouldn't date cait she seems like a bitch — rt "}]}
#
# 2017/05/08 23:22:16 - Fail : {"data": [{"text": "wait so you're single then?? — yes love, I'm a lonely sad single bean "}]}
#
# 2017/05/08 23:22:16 - Fail : {"data": [{"text": "are you and cait dating? — yep stunningfools "}]}
#
# 2017/05/08 23:22:33 - Fail : {"data": [{"text": "how did you glo up so quick? — well I've had this acc for about three years... but... "}]}
#
# 2017/05/08 23:23:23 - Fail : {"data": [{"text": "Even tho Idk you and I'm not mutuals with you I lov... — Aw that's so sweet babe you should dm me sometime I... "}]}
#
# 2017/05/08 23:23:23 - Fail : {"data": [{"text": "what does it mean are you gay? she's a person, f... — preach it baby ily "}]}
#
# 2017/05/08 23:23:27 - Fail : {"data": [{"text": "are you gay? — I'm alyssa "}]}
#
# 2017/05/08 23:25:31 - Fail : {"data": [{"text": "beamiller we know and we love you for that ️"}]}
#
# 2017/05/08 23:28:17 - Fail : {"data": [{"text": "˚ 　 ✧ 　· . .* * 　　 　　 　　 · 　　　 + 　　 ✷ 　.　 . ⋆ 　　　 　 · ˚ 　 . 　　　 　 　· 　 ⋆ 　　　　 ."}]}
# 7. yobitchmiranda : 1617
# 8
# 9. TommmMate : 787
#
# 2017/05/08 23:35:12 - Fail : {"data": [{"text": "BoliviaBigby ️"}]}
# 10
# 11. 4lilpretentious : 12174
#
# 2017/05/08 23:38:23 - Fail : {"data": [{"text": "Also, since when does it matter who follows who ?? Lol — it doesn't lmao "}]}
#
# 2017/05/08 23:38:23 - Fail : {"data": [{"text": "You're supposed to be a fan of the music, not a det... — yea exactly, plus let him live he can do what he wants "}]}
#
# 2017/05/08 23:38:23 - Fail : {"data": [{"text": "you and Bailey unfollowed eachother already ?!?! — yepp "}]}
#
# 2017/05/08 23:38:23 - Fail : {"data": [{"text": "I jus seen the pic tht Dalton deleted n it looks li... — did I ask ? "}]}
#
# 2017/05/08 23:38:37 - Fail : {"data": [{"text": "Your cc would be dead without Bailey and molly, bitch. — K I loveu too "}]}
#
# 2017/05/08 23:38:37 - Fail : {"data": [{"text": "who's molly — rapatitty "}]}
#
# 2017/05/08 23:38:37 - Fail : {"data": [{"text": "Dalton thinks she is. — Idk what we're talking about "}]}
#
# 2017/05/08 23:38:38 - Fail : {"data": [{"text": "I don't get why everything thinks Bailey is the shi... — Nope.. haven't really thought about it much tbh "}]}
#
# 2017/05/08 23:38:38 - Fail : {"data": [{"text": "Are you talking about Bailey because we all knew th... — Not everything is about Bailey k boo "}]}
#
# 2017/05/08 23:38:38 - Fail : {"data": [{"text": "Who are you indirecting??? — myself "}]}
#
# 2017/05/08 23:38:39 - Fail : {"data": [{"text": "Are the twitter police after you again? — No idea wym "}]}
#
# 2017/05/08 23:38:40 - Fail : {"data": [{"text": "I wonder if he'll seranade her w/Madison's favorite... — idk if that'd be good or bad lmao "}]}
#
# 2017/05/08 23:38:46 - Fail : {"data": [{"text": "That was obviously Madison in that pic he deleted. ... — you think so? idk looks like Avalon "}]}
#
# 2017/05/08 23:39:41 - Fail : {"data": [{"text": "What is your favorite position in bed when your wit... — all of em "}]}
#
# 2017/05/08 23:39:41 - Fail : {"data": [{"text": "Tweet nasty shit tonight. It's fun! — K boo I'm on it "}]}
#
# 2017/05/08 23:39:46 - Fail : {"data": [{"text": "Do u think Dalton is feeling good together with Ameet — welp I sure hope so "}]}
#
# 2017/05/08 23:39:47 - Fail : {"data": [{"text": "That profile pic is Lily. — it's Joaquin Phoenix he's an actor lmao "}]}
#
# 2017/05/08 23:39:47 - Fail : {"data": [{"text": "Lily has no pics posted and only had that one prof... — Um I know what Lily looks like lol. She's cute as h... "}]}
#
# 2017/05/08 23:39:47 - Fail : {"data": [{"text": "I didn't write that question but Lily Fallon is one... — Yea she is !! "}]}
#
# 2017/05/08 23:39:47 - Fail : {"data": [{"text": "Who are the hottest girls in this fandom? Name 10 — haha you tell me.. Name 10 go! "}]}
#
# 2017/05/08 23:39:56 - Fail : {"data": [{"text": "God your annoying. Do you ever think of just doing ... — Um I do volunteer and help kids asshole. Don't act ... "}]}
#
# 2017/05/08 23:39:56 - Fail : {"data": [{"text": "If you could fuck Dalton for 15 minutes only OR be ... — Def 3 days cuz we could do other stuff ;) "}]}
#
# 2017/05/08 23:39:57 - Fail : {"data": [{"text": "my tl is now Balls daddy and Dalt Dalt now — So what's the question lmao "}]}
#
# 2017/05/08 23:39:57 - Fail : {"data": [{"text": "Who's your papi? — Daddy Dalt Dalt "}]}
#
# 2017/05/08 23:39:59 - Fail : {"data": [{"text": "How much money would you have to be paid to be in a... — I'll do it for free.99 "}]}
#
# 2017/05/08 23:39:59 - Fail : {"data": [{"text": "Who's better at sucking balls whole? You or Dalton? — probably me, Dalton gets the silver medal "}]}
#
# 2017/05/08 23:40:00 - Fail : {"data": [{"text": "Who's trashier you or Bella Thorne? Also would you ... — idek Bella Thorne like that so prob me lmao .. hell... "}]}
#
# 2017/05/08 23:40:31 - Fail : {"data": [{"text": "my neighbor bob hit his ex-girlfriend then her cous... — Idk but Bob sounds like a fuck boy "}]}
#
# 2017/05/08 23:40:31 - Fail : {"data": [{"text": "do you have a gunt? — fuck off "}]}
#
# 2017/05/08 23:40:31 - Fail : {"data": [{"text": "Wow, sad to see people criticizing Dalton's perform... — yea exactly, the ppl in the audience loved it and t... "}]}
#
# 2017/05/08 23:40:38 - Fail : {"data": [{"text": "Why is everyone saying Dalton did a good job tonigh... — I liked it and thought it was pretty. He was a litt... "}]}
#
# 2017/05/08 23:40:43 - Fail : {"data": [{"text": "Did you ever post your meet and greet pics with Dal... — No "}]}
#
# 2017/05/08 23:41:01 - Fail : {"data": [{"text": "You would be so much prettier if you did your eyebr... — I don't wanna be prettier "}]}
#
# 2017/05/08 23:41:02 - Fail : {"data": [{"text": "post selfies — I hate selfies I have pics on ig kat_nobody "}]}
#
# 2017/05/08 23:41:02 - Fail : {"data": [{"text": "I wish we could be friends — why can't we? "}]}
#
# 2017/05/08 23:41:02 - Fail : {"data": [{"text": "You should do one of your polls. Who's more disgust... — Dang good idea! "}]}
#
# 2017/05/08 23:41:03 - Fail : {"data": [{"text": "wow you're actually like a savage and cool I like this — I like you tell me more "}]}
#
# 2017/05/08 23:41:03 - Fail : {"data": [{"text": "Bailey is dating dalton we all know they're not per... — Oh yea so am I, Dalton's a swinger he has like 10 ... "}]}
#
# 2017/05/08 23:41:03 - Fail : {"data": [{"text": "I think you get more hate than dalton — False, Dalton has way more haters lmao "}]}
#
# 2017/05/08 23:41:04 - Fail : {"data": [{"text": "Wait, you want to hook up with Bailey???? — How'd ya know??? "}]}
#
# 2017/05/08 23:41:04 - Fail : {"data": [{"text": "You two deserve each other. — how sweet I'm glad you're glad "}]}
#
# 2017/05/08 23:41:04 - Fail : {"data": [{"text": "Well Bailey is a nasty ass hoe so I understand the ... — gee I feel so much better now you told me that, any... "}]}
#
# 2017/05/08 23:41:04 - Fail : {"data": [{"text": "wtf you follow bailey — Yea keep up damn "}]}
#
# 2017/05/08 23:41:05 - Fail : {"data": [{"text": "You and Bailey are frollowing each other? Wtf? — frollowing lol.. why is that a big deal "}]}
#
# 2017/05/08 23:41:07 - Fail : {"data": [{"text": "Do you think dalton and Madison will get back toget... — Lol idk? I hope so tbh "}]}
#
# 2017/05/08 23:41:11 - Fail : {"data": [{"text": "Where was that last pic of dalton that you posted f... — a GC I think "}]}
#
# 2017/05/08 23:41:30 - Fail : {"data": [{"text": "you unfollowed me, I used to like you. — K. idk who u are. "}]}
#
# 2017/05/08 23:41:30 - Fail : {"data": [{"text": "Dalton is not here for you to sexualize him and cal... — that's not what he told me last night "}]}
#
# 2017/05/08 23:41:30 - Fail : {"data": [{"text": "What is the first thing you notice about a guy? — Eyes! I'm a sucker for eyes, they don't lie "}]}
#
# 2017/05/08 23:41:34 - Fail : {"data": [{"text": "I use to like you. You were always funny and friend... — I'm not trying to be mean. Sometimes I'm just irrit... "}]}
#
# 2017/05/08 23:41:35 - Fail : {"data": [{"text": "Hello my best friend I hope you have had a great da... — Hiiiii ily I hope u did too xxx "}]}
#
# 2017/05/08 23:41:37 - Fail : {"data": [{"text": "Why won't Dalton reply to /MY/ dms??!1! — He doesn't even read mine lol... He only comes in t... "}]}
#
# 2017/05/08 23:41:37 - Fail : {"data": [{"text": "I know you're probably excited that dalton replied ... — My sake and his? I think everything will be OK l... "}]}
#
# 2017/05/08 23:41:38 - Fail : {"data": [{"text": "You don't deserve all the shit you get. Some fans a... — ikr dang!! they have no chill tysm "}]}
#
# 2017/05/08 23:41:39 - Fail : {"data": [{"text": "HIII KAT ilysm and ur the moat wonderfulest person ... — Hiiiii ya aw tysm that's so sweet lol "}]}
#
# 2017/05/08 23:41:39 - Fail : {"data": [{"text": "Writing to yourself again? — I mean I talk to myself.. but I don't really have t... "}]}
#
# 2017/05/08 23:41:39 - Fail : {"data": [{"text": "So you're just gonna keep posting them and u don't ... — Um, what about how I feel? Dalton made everyone in ... "}]}
#
# 2017/05/08 23:41:40 - Fail : {"data": [{"text": "u always post Dalton's DMS? Ur rude and u should ju... — Sorry but nope. "}]}
#
# 2017/05/08 23:41:43 - Fail : {"data": [{"text": "so you do like it rough then?? — how'd u guess "}]}
#
# 2017/05/08 23:41:43 - Fail : {"data": [{"text": "ur trashy hoe — yes? "}]}
#
# 2017/05/08 23:41:43 - Fail : {"data": [{"text": "You don't think that's a lil inappropriate or gross... — bahahaha "}]}
#
# 2017/05/08 23:41:43 - Fail : {"data": [{"text": "Kat ily and your emo personality xxxxxxxx — AW I LOVE U xD "}]}
#
# 2017/05/08 23:41:44 - Fail : {"data": [{"text": "Fuck daddy? — k "}]}
#
# 2017/05/08 23:41:45 - Fail : {"data": [{"text": "Would you let Dalton fuck you in the ass — He can do whatever he wants "}]}
#
# 2017/05/08 23:41:45 - Fail : {"data": [{"text": "Kat, maybe it will make you feel better to take a b... — what are u my fucking mom?? "}]}
#
# 2017/05/08 23:41:46 - Fail : {"data": [{"text": "so much cursing and inappropriateness from u all th... — so what's the question? "}]}
#
# 2017/05/08 23:41:46 - Fail : {"data": [{"text": "Open your DMS and I'll buy you something pretty — This is the last one I'm answering. Kindly fuck off "}]}
#
# 2017/05/08 23:41:47 - Fail : {"data": [{"text": "Open them for me and watch. — GET READY THEN "}]}
#
# 2017/05/08 23:41:47 - Fail : {"data": [{"text": "Your dms aren't open... PLUS I'm a complete random ... — YOU'RE LYING "}]}
#
# 2017/05/08 23:41:47 - Fail : {"data": [{"text": "Hi you are so pretty! — hi.yea well I'm ugly on the inside "}]}
#
# 2017/05/08 23:41:47 - Fail : {"data": [{"text": "Why do you think I'm messing with you? I'm being se... — Maybe because you're anon??? DM if you're serious. ... "}]}
#
# 2017/05/08 23:41:47 - Fail : {"data": [{"text": "Because I like spoiling girlssss and I think I'd li... — stop messing with me!! for the love of god I'm not ... "}]}
#
# 2017/05/08 23:41:48 - Fail : {"data": [{"text": "Well shit... I was just curious because I want to b... — why would u want to buy me stuff anyways? "}]}
#
# 2017/05/08 23:41:48 - Fail : {"data": [{"text": "Age? — fuck off? "}]}
#
# 2017/05/08 23:41:48 - Fail : {"data": [{"text": "you unfollowed me — "}]}
#
# 2017/05/08 23:41:48 - Fail : {"data": [{"text": "suck my dick — K "}]}
#
# 2017/05/08 23:41:49 - Fail : {"data": [{"text": "Hi Dad. — Shut up please "}]}
#
# 2017/05/08 23:41:49 - Fail : {"data": [{"text": "Fuck me — fuck off "}]}
#
# 2017/05/08 23:41:49 - Fail : {"data": [{"text": "heeyyy is there a way to turn on notifications for ... — I don't know? I don't think so lol "}]}
#
# 2017/05/08 23:41:50 - Fail : {"data": [{"text": "You should go to sleep and have dirty dreams — OK bby ily nite "}]}
#
# 2017/05/08 23:41:50 - Fail : {"data": [{"text": "Baby girl? — Yea? "}]}
#
# 2017/05/08 23:41:50 - Fail : {"data": [{"text": "Can David Fuck me all the way to New York ? — I meannnnnn anything is possible "}]}
#
# 2017/05/08 23:41:50 - Fail : {"data": [{"text": "Baby girl is daddy makeing you feel things ? — he always makes me feel.. some ..thing lol "}]}
#
# 2017/05/08 23:41:51 - Fail : {"data": [{"text": "I like when you call me daddy! I want you to call m... — k daddy "}]}
#
# 2017/05/08 23:41:51 - Fail : {"data": [{"text": "I may slide into your DM's faster then I want to sl... — OK daddy u do that lmao "}]}
#
# 2017/05/08 23:41:51 - Fail : {"data": [{"text": "You like it rough of nice and slow baby? — talk dirty to me more daddy "}]}
#
# 2017/05/08 23:41:53 - Fail : {"data": [{"text": "Hi dad — Hi bby "}]}
#
# 2017/05/08 23:41:53 - Fail : {"data": [{"text": "Can I just fuck your brains out !??? — xD probably "}]}
#
# 2017/05/08 23:42:08 - Fail : {"data": [{"text": "You haven't posted your poetry in awhile.. I miss t... — Awww really. Yes actually I'm always writing tbh TY... "}]}
#
# 2017/05/08 23:42:08 - Fail : {"data": [{"text": "Thank you Kat for being original and genuine. Your... — That's so sweet thanku ily "}]}
#
# 2017/05/08 23:42:08 - Fail : {"data": [{"text": "just a thought but maybe delete this?... the hate ... — Nah I'm not gonna delete it over a some anon lames ... "}]}
#
# 2017/05/08 23:42:09 - Fail : {"data": [{"text": "Hi Kit Kat I hope u are OK — Hiiiii thanku you're sweet I'm OK "}]}
#
# 2017/05/08 23:42:09 - Fail : {"data": [{"text": "Name a couple of your followers you'd want to date — I don't want to name names but N/M/S lol "}]}
#
# 2017/05/08 23:42:19 - Fail : {"data": [{"text": "Are there any of your followers other than dalton t... — quite a few actually lol "}]}
#
# 2017/05/08 23:42:20 - Fail : {"data": [{"text": "No one finds out they're bipolar at your age - Ye... — Thanku Misti! "}]}
#
# 2017/05/08 23:42:20 - Fail : {"data": [{"text": "Thanks for admitting how fucking crazy you are — No problem boo I love you!! "}]}
#
# 2017/05/08 23:42:21 - Fail : {"data": [{"text": "Who would keep sending you hate — Someone who is lame asf and BORED OUT OF THEIR TINY... "}]}
#
# 2017/05/08 23:42:21 - Fail : {"data": [{"text": "I think people need to get their heads out of their... — Thank you so much Judith! I needed that ... "}]}
#
# 2017/05/08 23:42:21 - Fail : {"data": [{"text": "you're sick as fuck — aw come on that's not nice "}]}
#
# 2017/05/08 23:42:22 - Fail : {"data": [{"text": "Whoever is sending hate to Kat you stupid bitch you... — thanku "}]}
#
# 2017/05/08 23:42:22 - Fail : {"data": [{"text": "talking to yourself stupid cunt — I thought you'd like that "}]}
#
# 2017/05/08 23:42:22 - Fail : {"data": [{"text": "You're a dumb ass bitch — I love u too "}]}
#
# 2017/05/08 23:42:23 - Fail : {"data": [{"text": "You're lying aboutjust finding out about being Bi... — wtf is the matter with you? You know how dumb you s... "}]}
#
# 2017/05/08 23:42:28 - Fail : {"data": [{"text": "That explains why you're messed up. Pretending to b... — Daaaaamn lmao someones mad "}]}
#
# 2017/05/08 23:42:46 - Fail : {"data": [{"text": "It's funny how you and Tina use to bitch and hate o... — You act like I know what they are doing?. .I actual... "}]}
#
# 2017/05/08 23:42:56 - Fail : {"data": [{"text": "Being gay is a sin and so is being bi even tho it's... — I'm already in hell what else ya got? "}]}
#
# 2017/05/08 23:42:56 - Fail : {"data": [{"text": "HIIIIIIII kit kat — Hiiii "}]}
#
# 2017/05/08 23:43:01 - Fail : {"data": [{"text": "When you take over as Dalton of the United States d... — Nah I'm taking the White House WHAT "}]}
#
# 2017/05/08 23:43:02 - Fail : {"data": [{"text": "You're Dalton right? I'm a huge fan man. — danks man "}]}
#
# 2017/05/08 23:43:02 - Fail : {"data": [{"text": "damn we aren't friends but are people really presse... — I thought it was funny asf but ppl have no sense of... "}]}
#
# 2017/05/08 23:43:02 - Fail : {"data": [{"text": "They're seriously still bitching about the whole yo... — Ikr lmao. You think they miss me being Dalton? No I... "}]}
#
# 2017/05/08 23:43:02 - Fail : {"data": [{"text": "You are such a moron. — I'm probably smarter than you and your mom put tog... "}]}
#
# 2017/05/08 23:43:02 - Fail : {"data": [{"text": "Bitch I was just explaining it to you since you tho... — And when did I say it was an issue about that? You'... "}]}
#
# 2017/05/08 23:43:02 - Fail : {"data": [{"text": "I think people get so excited when they think dalto... — devasted lmao... Look I changed back didn't I?? A... "}]}
#
# 2017/05/08 23:43:03 - Fail : {"data": [{"text": "Hi soy here lol I find it stupid that people can't ... — !! Ikr? Haha and thanku "}]}
#
# 2017/05/08 23:43:03 - Fail : {"data": [{"text": "We really don't need the mom lectures from some of ... — Um OK? What are you telling me for? I'm only in con... "}]}
#
# 2017/05/08 23:43:05 - Fail : {"data": [{"text": "Damn people, hop off of Kat's ass. She didn't do an... — "}]}
#
# 2017/05/08 23:43:05 - Fail : {"data": [{"text": "God just admit it might be wrong. You're acting lik... — no! I won't, cuz I don't think it is. And yea ..qui... "}]}
#
# 2017/05/08 23:43:06 - Fail : {"data": [{"text": "It's fine when your just messing with your friends ... — Well my bad if I upset you.. I don't think I pulled... "}]}
#
# 2017/05/08 23:43:07 - Fail : {"data": [{"text": "Come on, can't we have a couple nights drama free. — Hey who's fighting Lmao? not me I'm just trying to ... "}]}
#
# 2017/05/08 23:43:07 - Fail : {"data": [{"text": "Making people feel stupid isn't funny — Are you sure? I'm gonna stay as Dalton till I die "}]}
#
# 2017/05/08 23:43:07 - Fail : {"data": [{"text": "Lol i understand where that anon was coming from ab... — the random ppl don't know me so I guess I get it bu... "}]}
#
# 2017/05/08 23:43:07 - Fail : {"data": [{"text": "You're really hurting some people's feelings preten... — Omg stop lmao.. How did I hurt anyone's feelings? i... "}]}
#
# 2017/05/08 23:43:08 - Fail : {"data": [{"text": "It's not funny what you're doing. It wasn't funny w... — I'm joking and i wasn't being mean to anyone chill "}]}
#
# 2017/05/08 23:43:51 - Fail : {"data": [{"text": "People need to chill, most people know Dalton can b... — for real tho. it's not like I was complaining. Ppl ... "}]}
#
# 2017/05/08 23:43:52 - Fail : {"data": [{"text": "That's so rude because Dalton is very kind to fans — I know he is. I wasn't trying to be rude smh I was ... "}]}
#
# 2017/05/08 23:43:52 - Fail : {"data": [{"text": "How would you act if you met Dalton face to face? — I have met him face to face and he was a salty bit... "}]}
#
# 2017/05/08 23:43:52 - Fail : {"data": [{"text": "Hi Kat luv ya — Hi ily 2 "}]}
#
# 2017/05/08 23:43:52 - Fail : {"data": [{"text": "Let's get stoned — xD I'm already there "}]}
#
# 2017/05/08 23:43:52 - Fail : {"data": [{"text": "Who's your daddy — Dalty is my daddy and he knows this "}]}
#
# 2017/05/08 23:43:53 - Fail : {"data": [{"text": "Hey hoe, how's life? — Never better thanks for asking "}]}
#
# 2017/05/08 23:44:27 - Fail : {"data": [{"text": "Have you ever really tried marijuana? — I didn't try it I smoked it "}]}
#
# 2017/05/08 23:44:27 - Fail : {"data": [{"text": "How many boyfriend and girlfriends have you had? — A couple of both "}]}
#
# 2017/05/08 23:44:29 - Fail : {"data": [{"text": "Wait I saw this on my tl and I remembered you poste... — I'm really not digging the questions about the dms.... "}]}
#
# 2017/05/08 23:44:29 - Fail : {"data": [{"text": "Has dalton ever dm'd you or answered your dm's — Nope "}]}
#
# 2017/05/08 23:44:30 - Fail : {"data": [{"text": "You look like you've lost weight — lol I've lost like 40lbs this year tbh "}]}
#
# 2017/05/08 23:44:31 - Fail : {"data": [{"text": "you're just trashy smh — I'm alot of things your tiny brain wouldn't even be... "}]}
#
# 2017/05/08 23:44:31 - Fail : {"data": [{"text": "I can tell you for a fact, dalton doesn't mind expl... — for a fact ? Lol yea I know for a fact he doesn't... "}]}
#
# 2017/05/08 23:44:31 - Fail : {"data": [{"text": "Did you have a happy new year — The best. thanks lol "}]}
#
# 2017/05/08 23:44:31 - Fail : {"data": [{"text": "I don't think Dalton would like the language and se... — well boo fucking hoo he doesn't own my account and ... "}]}
#
# 2017/05/08 23:44:31 - Fail : {"data": [{"text": "Who are daltons prettiest fans? Specific names please — specific names lmao ..All of Dalton's fans are ba... "}]}
#
# 2017/05/08 23:44:39 - Fail : {"data": [{"text": "I'm done with this fandom — I have a no drama policy on holidays I like, so I'l... "}]}
#
# 2017/05/08 23:44:39 - Fail : {"data": [{"text": "send nudes — sure thing anon I'm right on top of that xD "}]}
#
# 2017/05/08 23:44:39 - Fail : {"data": [{"text": "What are your New Years Eve plans? — get black out drunk and burn all my grievances "}]}
#
# 2017/05/08 23:44:39 - Fail : {"data": [{"text": "Come have a drink with me baby — Kk "}]}
#
# 2017/05/08 23:44:39 - Fail : {"data": [{"text": "Happy New year! — Thanks!! Happy New year to you too :) "}]}
#
# 2017/05/08 23:44:40 - Fail : {"data": [{"text": "Are you Stoned — That would be irresponsible "}]}
#
# 2017/05/08 23:44:40 - Fail : {"data": [{"text": "Fuckers in school telling me, always in the barber ... — Yo!! you fool lmao!!! Thanks for making me laug... "}]}
#
# 2017/05/08 23:44:43 - Fail : {"data": [{"text": "Hi Daddy — Kindly shut the fuck up "}]}
#
# 2017/05/08 23:44:43 - Fail : {"data": [{"text": "What's your favorite color — green "}]}
#
# 2017/05/08 23:44:43 - Fail : {"data": [{"text": "But how did I not know — How TF should I know "}]}
#
# 2017/05/08 23:44:52 - Fail : {"data": [{"text": "Why are so many of daltons fans bi??? Not judging a... — Haha idk I didn't know there was that many lmao "}]}
#
# 2017/05/08 23:44:55 - Fail : {"data": [{"text": "Do you know which Harry Potter house you're in? — I would probably be in Slytherin or Griffindor lol ... "}]}
#
# 2017/05/08 23:44:55 - Fail : {"data": [{"text": "Have you ever shot a gun before — I could answer this so smart ass lol but yes I have... "}]}
#
# 2017/05/08 23:44:55 - Fail : {"data": [{"text": "Do you play an instrument and if you don't what one... — I used to play the violin actually lol. But I reall... "}]}
#
# 2017/05/08 23:44:56 - Fail : {"data": [{"text": "What would be your ideal date night? As in what wou... — I like staying in, but going out to dinner and to t... "}]}
#
# 2017/05/08 23:44:56 - Fail : {"data": [{"text": "Straight or bi? — not straight "}]}
#
# 2017/05/08 23:44:56 - Fail : {"data": [{"text": "Has dalton ever tweeted/liked/retweeted you? — He liked my tweet like twice I think "}]}
#
# 2017/05/08 23:45:15 - Fail : {"data": [{"text": "Pls daddy pls !!!! — Don't ever again! "}]}
#
# 2017/05/08 23:45:15 - Fail : {"data": [{"text": "Come on daddy — I actually hate that word lmao "}]}
#
# 2017/05/08 23:45:15 - Fail : {"data": [{"text": "Daddy pls pls psl — OK cuz you said please "}]}
#
# 2017/05/08 23:45:15 - Fail : {"data": [{"text": "Daddy — I hate u "}]}
#
# 2017/05/08 23:45:18 - Fail : {"data": [{"text": "Do u have another favorite person besides Dalton? — Yea Tyler Joseph "}]}
#
# 2017/05/08 23:45:18 - Fail : {"data": [{"text": "Secretly do you like the way your own farts smell? — Yo wtf Howard Stern "}]}
#
# 2017/05/08 23:45:18 - Fail : {"data": [{"text": "Do you have a favorite Candy? — I love plain M&Ms, Salt water taffy, and chocolate ... "}]}
#
# 2017/05/08 23:45:19 - Fail : {"data": [{"text": "Hi Kat — Hiya "}]}
#
# 2017/05/08 23:45:19 - Fail : {"data": [{"text": "You never answered if you are single and how old yo... — Daaaammmmmnnnn xD yes yes you're right lmao "}]}
#
# 2017/05/08 23:45:19 - Fail : {"data": [{"text": "What's your dream job — Probably a writer or photographer "}]}
#
# 2017/05/08 23:45:19 - Fail : {"data": [{"text": "What's the sexiest thing about Dalton — Who said Dalton was sexy? xD "}]}
#
# 2017/05/08 23:45:19 - Fail : {"data": [{"text": "beep boop — What are you R2D2 lmao? "}]}
#
# 2017/05/08 23:45:20 - Fail : {"data": [{"text": "Hey gurl — Heyyyyy xD "}]}
#
# 2017/05/08 23:45:20 - Fail : {"data": [{"text": "If u knew the world was ending tomorrow what would ... — Enchiladas 40oz to freedom by Sublime My sister "}]}
#
# 2017/05/08 23:45:39 - Fail : {"data": [{"text": "If you don't give a specific age you must be old. — DM me I'll tell u "}]}
#
# 2017/05/08 23:45:41 - Fail : {"data": [{"text": "How old are you — Old enough but young enough ;) "}]}
#
# 2017/05/08 23:45:45 - Fail : {"data": [{"text": "Do u know a person that has blue eyes and is funny — Why yes, yes I do xD "}]}
#
# 2017/05/08 23:45:47 - Fail : {"data": [{"text": "Are you going to un-block people in 2017? — Probably not lol "}]}
#
# 2017/05/08 23:45:47 - Fail : {"data": [{"text": "Will you please post some pics — I have pics on ig kat_nobody lol "}]}
#
# 2017/05/08 23:45:48 - Fail : {"data": [{"text": "New Years resolution ? — Probably to take better care of myself lol "}]}
#
# 2017/05/08 23:45:48 - Fail : {"data": [{"text": "What did you eat for Christmas dinner? — The usual lol "}]}
#
# 2017/05/08 23:45:48 - Fail : {"data": [{"text": "Who's ur fav dalton fans — I love all nobodies I don't want to name names and ... "}]}
#
# 2017/05/08 23:45:48 - Fail : {"data": [{"text": "Do you regret anything fo this year? — No ragrets xD "}]}
#
# ...
#
# 2017/05/08 23:46:28 - Fail : {"data": [{"text": "I smell you from over there! Come shower with me — but I'm a bath girl sorry ;) "}]}
#
# 2017/05/08 23:46:30 - Fail : {"data": [{"text": "Man your brain is dirty wow — My brain is a lot of things lol "}]}
#
# 2017/05/08 23:46:31 - Fail : {"data": [{"text": "Dalton is a little baby we must protect him from al... — I'm on it xD "}]}
#
# 2017/05/08 23:46:32 - Fail : {"data": [{"text": "Like omg I can't believe you would even think about... — innocent bahahahaha "}]}
#
# 2017/05/08 23:46:33 - Fail : {"data": [{"text": "Do you like a bit of hair pulling & spanking ju... — Who doesn't :P "}]}
#
# 2017/05/08 23:46:35 - Fail : {"data": [{"text": "Would you like to go have pizza with me some time? — Only at the Stoned and Baked pizzeria xD "}]}
#
# 2017/05/08 23:46:35 - Fail : {"data": [{"text": "Why would he like strangers objectifying him? — I'm not objectifying him!! Do you even know the def... "}]}
#
# 2017/05/08 23:46:35 - Fail : {"data": [{"text": "What's your fav poem you've written & why — One I named No Escape cuz it's the only one that's ... "}]}
#
# 2017/05/08 23:46:36 - Fail : {"data": [{"text": "I don't understand why you have to talk about Dalto... — He loves it, and if you don't like it unfollow me, ... "}]}
#
# 2017/05/08 23:46:36 - Fail : {"data": [{"text": "What do you like to wear to bed? — Chanel no 5 "}]}
#
# 2017/05/08 23:46:37 - Fail : {"data": [{"text": "What's the sexiest thing about dalton — Damn that's a hard question cuz dat boy just exudes... "}]}
#
# 2017/05/08 23:46:37 - Fail : {"data": [{"text": "Where is one place you would like to travel to? — AMSTERDAM / PARIS / GREECE / ROME "}]}
#
# 2017/05/08 23:46:37 - Fail : {"data": [{"text": "If it was a really hot day & ur ice cream cone was ... — I wouldn't eat it quick cuz Ice cream hurts me lol "}]}
#
# 2017/05/08 23:46:37 - Fail : {"data": [{"text": "Besides Dalton, who is your celebrity crush, guy or... — Evan Peters / Billie Jo Armstrong Scarlet Johanss... "}]}
#
# 2017/05/08 23:46:38 - Fail : {"data": [{"text": "What's the best thing you ever put in your mouth?! Lol — Hot damn.. guess lol "}]}
#
# 2017/05/08 23:46:38 - Fail : {"data": [{"text": "If dalton was right infront of you, what would you ... — I think I'll save it for when I am in front of him ;) "}]}
#
# 2017/05/08 23:46:38 - Fail : {"data": [{"text": "If you had one day to live.. What would you go do? — I have no clue tbh is this day coming soon tho lol "}]}
#
# 2017/05/08 23:46:38 - Fail : {"data": [{"text": "Biggest turn on & turn off? — Turn on: a sense of humor, confidence, honesty, Dal... "}]}
#
# 2017/05/08 23:46:38 - Fail : {"data": [{"text": "Are you a good kisser? — I'm a good everything "}]}
#
# 2017/05/08 23:46:38 - Fail : {"data": [{"text": "What is a perfect date to you? — April 25th cuz you only need a light jacket xD "}]}
#
# 2017/05/08 23:46:39 - Fail : {"data": [{"text": "Whst do you want most for Christmas? — World peace xD "}]}
#
# 2017/05/08 23:46:39 - Fail : {"data": [{"text": "When's the last time you had a sex dream? & who about? — Every night and day about Dalton :P "}]}
#
# 2017/05/08 23:46:40 - Fail : {"data": [{"text": "What's your favorite thing about crystal? — She's honest N direct and calls me out :P "}]}
#
# 2017/05/08 23:46:40 - Fail : {"data": [{"text": "Favorite song out right now? — besides my daddy's lol.. You don't own me, bad thin... "}]}
#
# 2017/05/08 23:47:01 - Fail : {"data": [{"text": "Sorry my last post was rude but it was true ...... — idk which one that I'm stupid or disrespectful? Lol "}]}
#
# 2017/05/08 23:47:01 - Fail : {"data": [{"text": "Guarantee the nasty comments on here are from the g... — probably lol we'll never know xD "}]}
#
# 2017/05/08 23:47:01 - Fail : {"data": [{"text": "I wish these crazy cunts would stop hateing on you ... — Lol you can't fix stupid "}]}
#
# 2017/05/08 23:47:02 - Fail : {"data": [{"text": "Wait wait No I like your right eye — lmao jeez make up your mind xD "}]}
#
# 2017/05/08 23:47:02 - Fail : {"data": [{"text": "I like your left eye — good choice xD "}]}
#
# 2017/05/08 23:47:02 - Fail : {"data": [{"text": "You don't think he'd find those sexually explicit t... — wtf lmao what do I rt? and no didn't I already do t... "}]}
#
# 2017/05/08 23:47:04 - Fail : {"data": [{"text": "you think it's funny to disrespect Dalton and day d... — !!! I adore Dalton and I don't say anything I THIN... "}]}
#
# 2017/05/08 23:47:04 - Fail : {"data": [{"text": "I like your eye — which one the left or right lmao? "}]}
#
# 2017/05/08 23:47:07 - Fail : {"data": [{"text": "I'm sorry I'm just done with this Fandom — Don't be done just cuz a couple of assholes lol the... "}]}
#
# 2017/05/08 23:47:08 - Fail : {"data": [{"text": "Hey baby how are you — Hey baby I'm good how are u ;) "}]}
#
# 2017/05/08 23:47:08 - Fail : {"data": [{"text": "u ask plpl to talk to u but then u never answer my ... — Lol I'm sorry I only deleted a few that were about ... "}]}
#
# 2017/05/08 23:47:13 - Fail : {"data": [{"text": "*insert something triggereing* — Damn I gotta do all the work xD "}]}
#
# 2017/05/08 23:47:13 - Fail : {"data": [{"text": "Why do people ask you weird shit on here — Lol right xD "}]}
#
# 2017/05/08 23:47:13 - Fail : {"data": [{"text": "So how's dan? — Catching up on sleep cuz I wear him out xP "}]}
#
# 2017/05/08 23:47:16 - Fail : {"data": [{"text": "just keep your mouth shut — I'm not gonna shut up just cuz you want me to lmao "}]}
#
# 2017/05/08 23:47:16 - Fail : {"data": [{"text": "Please tell that dumbass saige to shut the fuck up.... — Nah I feel pretty relevant rn lmao but danks for th... "}]}
#
# 2017/05/08 23:47:17 - Fail : {"data": [{"text": "You and Sabrina are a couple of obese middle aged f... — it hurts me when u say that. I have moved on lmao ... "}]}
#
# 2017/05/08 23:47:17 - Fail : {"data": [{"text": "Butt out you irrelevant sack of shit. — Don't be a pussy me "}]}
#
# 2017/05/08 23:47:27 - Fail : {"data": [{"text": "What would you do if you became 500ft tall (people ... — maybe scream like a baby and accidently step on som... "}]}
#
# 2017/05/08 23:47:27 - Fail : {"data": [{"text": "Everything but red — I hate red "}]}
#
# 2017/05/08 23:47:27 - Fail : {"data": [{"text": "Death — "}]}
#
# 2017/05/08 23:47:30 - Fail : {"data": [{"text": "Who do you want to break the mutual with — No one at the moment..but I would just unfollow the... "}]}
#
# 2017/05/08 23:47:31 - Fail : {"data": [{"text": "What's your least favorite thing — Lol my least fave thing is when ppl ask me what my ... "}]}
#
# 2017/05/08 23:47:31 - Fail : {"data": [{"text": "What color do you hate — Red brown N yellow lol "}]}
#
# 2017/05/08 23:47:33 - Fail : {"data": [{"text": "Hi I like your face — hi danks :) "}]}
#
# 2017/05/08 23:47:40 - Fail : {"data": [{"text": "bleach — yes "}]}
#
# 2017/05/08 23:47:40 - Fail : {"data": [{"text": "would you rather eat a crayon or eraser — How bout I just go crazy and eat em both? "}]}
#
# 2017/05/08 23:47:40 - Fail : {"data": [{"text": "Would you rather adopt a panda or baby unicorn — neither I already have a baby pegasus "}]}
#
# 2017/05/08 23:47:41 - Fail : {"data": [{"text": "Star wars prequels or originals it's for science? — but I like them all? lol "}]}
#
# 2017/05/08 23:47:42 - Fail : {"data": [{"text": "I love you from Lily — I love you and your lol "}]}
#
# 2017/05/08 23:47:43 - Fail : {"data": [{"text": "What your favorite thing about dalton? — I love his music and his heart and the fact that he... "}]}
#
# 2017/05/08 23:47:44 - Fail : {"data": [{"text": "When can I get your number? — I forgot my number "}]}
#
# 2017/05/08 23:47:44 - Fail : {"data": [{"text": "What's your biggest pet peeve? — mean people "}]}
#
# 2017/05/08 23:47:48 - Fail : {"data": [{"text": "What's your biggest turn on about a person? — A sense of humor xD "}]}
#
# 2017/05/08 23:47:48 - Fail : {"data": [{"text": "come up with a few lines of poetry on the spot? — She has this magic in her tears when she cries all ... "}]}
#
# 2017/05/08 23:47:49 - Fail : {"data": [{"text": "What is the most sexually intriguing thing you've e... — Damn xD a lady never tells lmao "}]}
#
# 2017/05/08 23:47:52 - Fail : {"data": [{"text": "ur hot — <3 Ur hot "}]}
#
# 2017/05/08 23:47:53 - Fail : {"data": [{"text": "So what's the point of having this if you're not go... — holy hell you're annoying . What are you not gettin... "}]}
#
# 2017/05/08 23:47:54 - Fail : {"data": [{"text": "So now you're going to start with the whole dicks o... — yep that's how I like em O U T "}]}
#
# 2017/05/08 23:47:54 - Fail : {"data": [{"text": "do you think Dalton plays favorites — Doesn't everyone have favorite shit xD "}]}
#
# 2017/05/08 23:47:55 - Fail : {"data": [{"text": "I don't care what other say, your really cute. Wan... — I don't drink, I'll buy ya dinner tho xD "}]}
#
# 2017/05/08 23:47:55 - Fail : {"data": [{"text": "lol. so have you ever seen that happen to your brot... — No not really, but if i did I would probably ask hi... "}]}
#
# 2017/05/08 23:47:55 - Fail : {"data": [{"text": "lmfao thanks. so do you have a brother though? — Yea I do lol "}]}
#
# 2017/05/08 23:47:55 - Fail : {"data": [{"text": "is it okay to ask my brother what it feels like to ... — If it was me I'd be more mad then embarrassed lmao ... "}]}
#
# 2017/05/08 23:47:58 - Fail : {"data": [{"text": "Hello I love you — Hello I love you more "}]}
#
# 2017/05/08 23:47:59 - Fail : {"data": [{"text": "did you eat Dalton — twice "}]}
#
# 2017/05/08 23:48:00 - Fail : {"data": [{"text": "You're my fave ho — <3 ily "}]}
#
# 2017/05/08 23:48:00 - Fail : {"data": [{"text": "you're a whore and I hate u — Lmao xD it's *ho "}]}
#
# 2017/05/08 23:51:41 - Fail : {"data": [{"text": "DanielRapattoni what does a straight™ pose look like to you?"}]}
#
# 2017/05/08 23:55:10 - Fail : {"data": [{"text": "mimimoir3 DanielRapattoni gosh what is so wrong with saying i love cake by the beach ¯\_(ツ)_/¯"}]}
#
# 2017/05/08 23:55:42 - Fail : {"data": [{"text": "mimimoir3 DaltonRapattoni ¯\_(ツ)_/¯"}]}
#
# 2017/05/08 23:55:46 - Fail : {"data": [{"text": "i have to work in a group and do a presentation ON HALLOWEEN :\"}]}
#
# 2017/05/08 23:56:12 - Fail : {"data": [{"text": "idk what's more lame, the fact that i did it or that i still remember it :\"}]}
#
# 2017/05/09 00:05:48 - Fail : {"data": [{"text": "twiixn well if you're worried about it you can always oh idk not create drama ¯\_(ツ)_/¯"}]}
#
# 2017/05/09 00:05:53 - Fail : {"data": [{"text": "Nora__Lyn Paige_wj Tinaxo77 what did i say ¯\_(ツ)_/¯"}]}
#
# 2017/05/09 00:07:48 - Fail : {"data": [{"text": "I think it's pretty self explanatory you pay 100 bucks and get to eat Dalton ¯\_(ツ)_/¯"}]}
#
# 2017/05/09 00:07:54 - Fail : {"data": [{"text": "No ragrets ¯\_(ツ)_/¯ DaltonRapattoni"}]}
#
# 2017/05/09 00:08:14 - Fail : {"data": [{"text": "Next time just me ¯\_(ツ)_/¯"}]}
#
# 2017/05/09 00:08:31 - Fail : {"data": [{"text": "ppl keep unfollowing me and I'm too lazy to figure out who it is or to even care ¯\_(ツ)_/¯"}]}
# 12
# 13. Luucekay : 797
#
# 2017/05/09 00:16:29 - Fail : {"data": [{"text": "victoriamcc1 p.s I'm now hiring for a walking/gym buddy cause I've been gaining weight too ️"}]}
# 14. Rationalchaos : 1333
# 15
# 16. AwesomeAsh : 272
# 17. matthewRvincent : 1711
#
# 2017/05/09 00:28:44 - Fail : {"data": [{"text": "How I spent my snowday, too 가끔은 고양이와 춤을 춥시다 "}]}
# 18. _rachelsarahxo : 955
# 19. Brakywaki : 1869
#
# 2017/05/09 00:37:54 - Fail : {"data": [{"text": "Get badges & buy stuff to earn XP and grab free games—it's the sweetest Summer Sale ever! "}]}
#
# 2017/05/09 00:38:00 - Fail : {"data": [{"text": "When asked for Jon Lovitz I THROW TRASH ALL FUCKIN WEEK what? Holy shit i wanna be dead in my wife! Hey! — "}]}
# 20. colinfarrelfan : 2883
#
# 2017/05/09 00:40:53 - Fail : {"data": [{"text": "diiazLoL was only a matter of time tbh. i cant stay calm when i got a guy called Ömer on my team"}]}
#
# 2017/05/09 00:41:21 - Fail : {"data": [{"text": "cowennnn how much is that in €"}]}
#
# 2017/05/09 00:41:51 - Fail : {"data": [{"text": "germansinaii wir haben ganz europa erobert und versuchten die weiße rasse vor den juden zu schützen, und jetzt kommen die immigranten bah"}]}
#
# 2017/05/09 00:43:39 - Fail : {"data": [{"text": "(づ｡◕‿‿◕｡)づ"}]}
#
# 2017/05/09 00:45:12 - Fail : {"data": [{"text": "wtf new xbone 1 with halo is only like 250€ feelsgood"}]}
#
# 2017/05/09 00:48:12 - Fail : {"data": [{"text": "dragoncon (Vine by MethBlunts™) "}]}
#
# 2017/05/09 00:48:18 - Fail : {"data": [{"text": "角質 角質 角質 "}]}
# 21. opalpence : 497
# 22. right2hell : 187
#
# 2017/05/09 00:50:36 - Fail : {"data": [{"text": "(*´ω｀*)"}]}
#
# 2017/05/09 00:50:37 - Fail : {"data": [{"text": "( ˘ω˘ ;) mr ugy man"}]}
# 23. clarrasinco : 871
#
# 2017/05/09 00:53:52 - Fail : {"data": [{"text": "I don't want to hurt you or anybody so please forget about me. Just try. Find yourself a better friend. ― Nina LaCour, Hold Still
# clarrasinco	clarrasinco	2016-04-21 02:00:13	Life has become unbearable ... forgive me. -- Dalida
# clarrasinco	clarrasinco	2016-04-21 01:57:51	Eureka!!!
# clarrasinco	clarrasinco	2016-04-21 01:57:40	What if?
# clarrasinco	clarrasinco	2016-04-21 01:55:32	Because, life goes on, with or without you. And it's easier without you. No burden.
# clarrasinco	clarrasinco	2016-04-21 01:54:23	How could someone who knows a friend is going through something and not do anything about it?
# clarrasinco	clarrasinco	2016-04-21 01:53:16	Honestly, I still wait for text messages that I know I won't receive.
# clarrasinco	clarrasinco	2016-04-20 01:35:43	Dear God, I'm ashamed of the people I chose. Or did they choose me?
# clarrasinco	clarrasinco	2016-04-20 01:33:16	If you were a friend and we haven't talked in a while, chances are... alamna
# clarrasinco	clarrasinco	2016-04-20 01:30:11	You say you miss me, you have not done anything. excuses
# clarrasinco	clarrasinco	2016-04-20 01:27:21	I thought it was impossible to hate the people you love. Pwede pala.
# clarrasinco	clarrasinco	2016-04-20 01:18:33	Dispensable. Wow. Big word.
# clarrasinco	clarrasinco	2016-04-20 01:14:22	Zero chance.
# clarrasinco	clarrasinco	2016-04-20 01:10:33	But then you'll regret you did not reach out.
# clarrasinco	clarrasinco	2016-04-20 01:09:04	At least, the last memories I could give you were all good ones. Think of our last time together, diba, ok naman?
# clarrasinco	clarrasinco	2016-04-20 00:29:02	Uh-huh. Nope.
# clarrasinco	clarrasinco	2016-04-20 00:23:32	Received a package with 10 tablets of my meds. But I've stopped drinking for a month now. No plans to continue.
# clarrasinco	clarrasinco	2016-04-19 22:05:02	Hirap na hirap Alaska sa TNT. Ang galing ni Jayson Castro! Infer, kinabahan ako sa tres ni Troy. Ganda nung play eh.
# clarrasinco	clarrasinco	2016-04-19 21:36:35	Buti Alaska nanalo kundi gutom aabutin ni Billy. Hahaha.
# clarrasinco	clarrasinco	2016-04-19 17:36:14	Billy and I on our way to Araneta for our impromptu PBA date.
# clarrasinco	clarrasinco	2016-04-19 15:35:10	Habol pa natin si All The Bright Places! Pati ba si Looking for Alaska? Pag kinaya.
# clarrasinco	clarrasinco	2016-04-19 15:32:34	Hmmm, i'll reread Playlist for the Dead and My Heart & Other Blackholes. Sige na nga pati It's Kind Of A Funny Story. alamna
# clarrasinco	clarrasinco	2016-04-19 15:27:28	I'm almost at the end!
# clarrasinco	clarrasinco	2016-04-19 15:25:53	I could count the number of people I asked to check up on me. And all of them did not. Thanks for proving I chose the wrong people.
# clarrasinco	clarrasinco	2016-04-19 15:25:12	I'm not mad because of something you did but because of something you did not do.
# clarrasinco	clarrasinco	2016-04-19 15:24:55	You promised you will always be there but you're only there when it's convenient. So, no thanks. Not what I need. MomordicaCharantia
# clarrasinco	clarrasinco	2016-04-19 04:29:36	Haven't gone to my doc in a month and I stopped my meds altogether. Keri, di naman daw kelangan! mamaru
# clarrasinco	clarrasinco	2016-04-19 04:20:25	Dibenj? dramarama
# clarrasinco	clarrasinco	2016-04-19 04:19:31	Inumaga nako kakalaro ng Color Switch. Si Billy kasi eh, lakas makaimpluwensya!
# clarrasinco	clarrasinco	2016-04-19 04:18:00	Nobody knew how angry he was until it was too late. (replace angry with lonely) alamna IsItTooLateNowToSaySorry"}]}

# %% [markdown]
# ## Out

# %%
file_dir = 'new_bipolar/'
col = ['id', 'screen', 'datetime', 'text','emotion1','emotion2','ambiguous','sentiment']
emo_user_tweet_list = [pd.read_csv(file_dir+file, delimiter = '\t', names = col) for file in os.listdir(file_dir)]

# %%
for i, user_tweets in enumerate(emo_user_tweet_list):
    emo_user_tweet_list[i].index = pd.to_datetime(user_tweets.datetime)
    del emo_user_tweet_list[i]['id']
    del emo_user_tweet_list[i]['datetime']
    emo_user_tweet_list[i] = emo_user_tweet_list[i].rename( columns = {'screen':'name','emotion1':'emotion','emotion2':'emotion_2','sentiment':'polarity'})

# %%
for i, user_tweets in enumerate(emo_user_tweet_list):
    emo_user_tweet_list[i] = emo_user_tweet_list[i].sort_index().fillna(0)
    emo_user_tweet_list[i]['dt'] = np.zeros(user_tweets.shape[0],dtype=float)
    emo_user_tweet_list[i].loc[:-1,'dt'] = (user_tweets.index[1:].values - user_tweets.index[:-1].values).astype('timedelta64[s]') / np.timedelta64(60, 's')

# %%
# export
for i in range(len(emo_user_tweet_list)):
    emo_user_tweet_list[i].to_pickle('new_bipolar_pickle/bipolar_clean'+str(i+400)+'.p')
